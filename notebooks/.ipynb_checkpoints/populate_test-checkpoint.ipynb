# %%
try:
    device.Device.drop()
except:
    []
try:
    ephys.ElectrodeConfig.drop()
except:
    []
try:
    session.Session.drop()
except:
    []
try:
    intervals.drop()
except:
    []
try:
    task.drop()
except:
    []
# Out:
# `device`.`device` (1 tuples)
# `ephys`.`_electrode_config__electrode_group` (27 tuples)
# `ephys`.`_units` (74 tuples)
# `ephys`.`_electrode_config__electrode` (108 tuples)
# `session`.`_session__data_acq_device` (1 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.  Restart kernel.
# `ephys`.`_electrode_config` (1 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.  Restart kernel.
# `session`.`_session` (1 tuples)
# `session`.`_experimenter_list` (1 tuples)
# `session`.`_experimenter_list__experimenter` (1 tuples)
# `franklab`.`interval_list` (81 tuples)
# `task`.`_task_epoch` (7 tuples)
# `ephys`.`_l_f_p` (0 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.  Restart kernel.

# %%
cd ../franklabnwb
# Out:
# /Users/loren/Src/NWB/franklabnwb/franklabnwb

# %%
# %load_ext autoreload
# %autoreload 2

import datajoint as dj
import os

import createprobes
import probe
import nwb_dj
import session
import ephys
import device
import lab
import task
import intervals


import pynwb

from franklabnwb import fl_ns_path
import franklabnwb.nspike_helpers as ns
import franklabnwb.query_helpers as qu
import franklabnwb.fl_extension as fle
import franklabnwb.fl_extension as flh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read in subject information from an NWB file
data_dir, data_src = os.path.expanduser('/data/mkarlsso/Bon/'), 'local'
#data_dir, data_src = os.path.expanduser('~/Data/FrankData/kkay/Bon/'), 'local'
nwb_dir = data_dir + 'NWB/'
# data_dir, data_src = os.path.expanduser('~/Data/FrankData/CRCNS/Bon'), 'CRCNS'

anim = 'bon' 
day = 4 # below we'll code date as 2006-Jan-'Day'
day_str = '%02d' % day
nwb_file_name = nwb_dir + anim + day_str + '.nwb'

assert os.path.exists(nwb_file_name), 'NWB File does not exist: "{}".'.format(nwb_file_name)

# %%
device.Device()
# Out:
# *device_name
# +------------+
#
#  (Total: 0)

# %%
probe.ProbeInfo()
# Out:
# *probe_type    probe_descript num_shanks
# +------------+ +------------+ +------------+
# 32c-2s8mm6cm-2 32 channel pol 2
# tetrode        tetrode made f 1
#  (Total: 2)

# %%
createprobes.add_probes()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-9-e1c02d9558ce> in <module>
# ----> 1 createprobes.add_probes()
#
# ~/Src/NWB/franklabnwb/franklabnwb/createprobes.py in add_probes()
#      13     probetype_dict['num_shanks'] = 1
#      14     probetype_dict['probe_description'] = 'tetrode made from 4 12.5 um nichrome wires'
# ---> 15     probe.ProbeInfo.insert1(probetype_dict, allow_direct_insert=True, replace=True)
#      16     probe.ProbeInfo.Shank.insert1(['tetrode', 0])
#      17     for i in range(4):
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/datajoint/table.py in insert1(self, row, **kwargs)
#     147         For kwargs, see insert()
#     148         """
# --> 149         self.insert((row,), **kwargs)
#     150
#     151     def insert(self, rows, replace=False, skip_duplicates=False, ignore_extra_fields=False, allow_direct_insert=None):
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/datajoint/table.py in insert(self, rows, replace, skip_duplicates, ignore_extra_fields, allow_direct_insert)
#     305                                if skip_duplicates else ''))
#     306                 self.connection.query(query, args=list(
# --> 307                     itertools.chain.from_iterable((v for v in r['values'] if v is not None) for r in rows)))
#     308             except (OperationalError, InternalError, IntegrityError) as err:
#     309                 if err.args[0] == server_error_codes['command denied']:
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/datajoint/connection.py in query(self, query, args, as_dict, suppress_warnings, reconnect)
#     146                     # suppress all warnings arising from underlying SQL library
#     147                     warnings.simplefilter("ignore")
# --> 148                 cur.execute(query, args)
#     149         except (err.InterfaceError, err.OperationalError) as e:
#     150             if is_connection_error(e) and reconnect:
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/envs/default/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# IntegrityError: (1451, 'Cannot delete or update a parent row: a foreign key constraint fails (`probe`.`probe_info__shank`, CONSTRAINT `probe_info__shank_ibfk_1` FOREIGN KEY (`probe_type`) REFERENCES `probe_info` (`probe_type`) ON UPDATE CASCADE)')

# %%
io = pynwb.NWBHDF5IO(nwb_file_name, mode='r')
nwbf = io.read()

# %%
conn = dj.conn()
conn.commit_transaction()

# %%
task.ApparatusInfo()
# Out:
# *apparatus_nam
# +------------+
# Sleep Box
# TrackA
# TrackB
#  (Total: 3)

# %%
nwb_dj.NWBPopulate([nwb_file_name])
# Out:
# Skipping task Sleep; already in schema
#
# Skipping task W-Alternation; already in schema
#
# Skipping apparatus Sleep Box; already in schema
#
# Skipping apparatus TrackA; already in schema
#
# Skipping apparatus TrackB; already in schema

# %%
dj.Diagram(ephys)+dj.Diagram(session)+dj.Diagram(probe)+dj.Diagram(lab)+dj.Diagram(intervals)

# %%
task.TaskEpoch()
# Out:
# *nwb_file_name *epoch    task_name      apparatus_name interval_name  task_object_id apparatus_obje exposure
# +------------+ +-------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+
# /data/mkarlsso 0         Sleep          Sleep Box      task epoch 0   -1             -1             -1
# /data/mkarlsso 1         W-Alternation  TrackB         task epoch 1   -1             -1             3
# /data/mkarlsso 2         Sleep          Sleep Box      task epoch 2   -1             -1             -1
# /data/mkarlsso 3         W-Alternation  TrackB         task epoch 3   -1             -1             4
# /data/mkarlsso 4         Sleep          Sleep Box      task epoch 4   -1             -1             -1
# /data/mkarlsso 5         W-Alternation  TrackA         task epoch 5   -1             -1             14
# /data/mkarlsso 6         Sleep          Sleep Box      task epoch 6   -1             -1             -1
#  (Total: 7)

# %%
task.Task.TaskEpoch()
# Out:
# *nwb_file_name task_name     apparatus_name interval_name  exposure
# +------------+ +-----------+ +------------+ +------------+ +----------+
#
#  (Total: 0)
