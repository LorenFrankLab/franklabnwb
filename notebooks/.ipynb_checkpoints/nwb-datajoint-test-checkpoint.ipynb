# %%
# %load_ext autoreload
# %autoreload 2

import pynwb

# General dependencies
import os
import numpy as np

# Time
from datetime import datetime
from dateutil import tz

# Helpers for parsing Frank Lab Matlab data
import convert_nspike.nspike_helpers as ns 
import nwb_query.query_helpers as qu

# Frank Lab PyNWB extensions and extension-related helpers
import fl_extension as fle
import fl_extension_helpers as flh

# Plotting
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
mdates.rcParams.update({'date.autoformatter.microsecond': '%H:%M:%S.%f'})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nwb_filename = '/data/mkarlsso/Bon/NWB/bon03.nwb'
with pynwb.NWBHDF5IO(nwb_filename, mode='r') as ior:
    nwbf = ior.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ff7e4bea340a> in <module>
#       1 nwb_filename = '/data/mkarlsso/Bon/NWB/bon03.nwb'
# ----> 2 with pynwb.NWBHDF5IO(nwb_filename, mode='r') as ior:
#       3     nwbf = ior.read()
#       4
#
# NameError: name 'pynwb' is not defined

# %%
# temporary hack until Subject writing works
nwbf.Subject = pynwb.file.Subject(age=None, 
                                  description='Long Evans Rat', 
                                  genotype='WT', sex='M', 
                                  species='Rat', 
                                  subject_id='Bond', 
                                  weight=None, 
                                  date_of_birth=None)
nwbf.Subject
# Out:
# subject <class 'pynwb.file.Subject'>
# Fields:
#   description: Long Evans Rat
#   genotype: WT
#   sex: M
#   species: Rat
#   subject_id: Bond

# %%
# Out:
# {'_Container__name': 'root',
#  '_Container__parent': None,
#  '_Container__container_source': '/data/mkarlsso/Bon/NWB/bon03.nwb',
#  '_Container__children': [
#   LFP <class 'pynwb.ecephys.LFP'>
#   Fields:
#     decomposition_series: { }
#     electrical_series: { boneeg-3-1 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-10 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-11 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-12 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-13 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-14 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-15 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-17 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-18 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-19 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-2 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-20 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-21 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-22 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-23 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-24 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-25 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-27 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-28 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-29 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-3 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-30 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-4 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-5 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-6 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-7 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-8 <class 'pynwb.ecephys.ElectricalSeries'> },
#
#   Behavior <class 'pynwb.base.ProcessingModule'>
#   Fields:
#     data_interfaces: { Head Direction <class 'pynwb.behavior.CompassDirection'>,  Position <class 'pynwb.behavior.Position'>,  Sleep <class 'fl_extension.Task'>,  Sleep Box <class 'fl_extension.Apparatus'>,  Speed <class 'pynwb.behavior.BehavioralTimeSeries'>,  TrackA <class 'fl_extension.Apparatus'>,  TrackB <class 'fl_extension.Apparatus'>,  W Alternation <class 'fl_extension.Task'> }
#     description: Behavioral variables,
#
#   epochs <class 'pynwb.epoch.TimeIntervals'>
#   Fields:
#     colnames: ('start_time', 'stop_time', 'exposure', 'task', 'apparatus', 'tags')
#     columns: [
#   start_time <class 'pynwb.core.VectorData'>
#   Fields:
#     description: Start time of epoch, in seconds
#   ,
#   stop_time <class 'pynwb.core.VectorData'>
#   Fields:
#     description: Stop time of epoch, in seconds
#   ,
#   exposure <class 'pynwb.core.VectorData'>
#   Fields:
#     description: number of exposures to this environment
#   ,
#   task <class 'pynwb.core.VectorData'>
#   Fields:
#     description: behavioral task for this epoch
#   ,
#   apparatus <class 'pynwb.core.VectorData'>
#   Fields:
#     description: behavioral apparatus for this epoch
#   ,
#   tags_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: tags <class 'pynwb.core.VectorData'>
#   ,
#   tags <class 'pynwb.core.VectorData'>
#   Fields:
#     description: user-defined tags
#   ]
#     description: experimental epochs
#     id: id <class 'pynwb.core.ElementIdentifiers'>,
#
#   units <class 'pynwb.misc.Units'>
#   Fields:
#     colnames: ('cluster_name', 'spike_times', 'obs_intervals', 'electrodes')
#     columns: [
#   cluster_name <class 'pynwb.core.VectorData'>
#   Fields:
#     description: (str) cluster name from clustering software
#   ,
#   spike_times_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: spike_times <class 'pynwb.core.VectorData'>
#   ,
#   spike_times <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the spike times for each unit
#   ,
#   obs_intervals_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: obs_intervals <class 'pynwb.core.VectorData'>
#   ,
#   obs_intervals <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the observation intervals for each unit
#   ,
#   electrodes_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: electrodes <class 'pynwb.core.DynamicTableRegion'>
#   ,
#   electrodes <class 'pynwb.core.DynamicTableRegion'>
#   Fields:
#     description: the electrodes that each spike unit came from
#     table: electrodes <class 'pynwb.core.DynamicTable'>
#   ]
#     description: Autogenerated by NWBFile
#     id: id <class 'pynwb.core.ElementIdentifiers'>,
#
#   electrodes <class 'pynwb.core.DynamicTable'>
#   Fields:
#     colnames: ('x', 'y', 'z', 'imp', 'location', 'filtering', 'group', 'group_name')
#     columns: [
#   x <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the x coordinate of the channel location
#   ,
#   y <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the y coordinate of the channel location
#   ,
#   z <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the z coordinate of the channel location
#   ,
#   imp <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the impedance of the channel
#   ,
#   location <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the location of channel within the subject e.g. brain region
#   ,
#   filtering <class 'pynwb.core.VectorData'>
#   Fields:
#     description: description of hardware filtering
#   ,
#   group <class 'pynwb.core.VectorData'>
#   Fields:
#     description: a reference to the ElectrodeGroup this electrode is a part of
#   ,
#   group_name <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the name of the ElectrodeGroup this electrode is a part of
#   ]
#     description: metadata about extracellular electrodes
#     id: id <class 'pynwb.core.ElementIdentifiers'>,
#
#   03-01 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 1 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-02 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 2 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-03 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 3 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-04 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 4 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-05 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 5 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-06 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 6 located in ? on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: ?,
#
#   03-07 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 7 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-08 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 8 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-10 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 10 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-11 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 11 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-12 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 12 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-13 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 13 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-14 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 14 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-15 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 15 located in ? on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: ?,
#
#   03-17 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 17 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-18 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 18 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-19 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 19 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-20 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 20 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-21 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 21 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-22 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 22 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-23 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 23 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-24 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 24 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-25 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 25 located in CA3 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA3,
#
#   03-27 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 27 located in ??? on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: ???,
#
#   03-28 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 28 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-29 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 29 located in CA1 on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: CA1,
#
#   03-30 <class 'pynwb.ecephys.ElectrodeGroup'>
#   Fields:
#     description: tetrode 30 located in Reference on day 3
#     device: NSpike acquisition system <class 'pynwb.device.Device'>
#     location: Reference,
#
#   NSpike acquisition system <class 'pynwb.device.Device'>
#   Fields:],
#  '_Container__modified': False,
#  '_NWBBaseType__fields': {'acquisition': {'LFP':
#    LFP <class 'pynwb.ecephys.LFP'>
#    Fields:
#      decomposition_series: { }
#      electrical_series: { boneeg-3-1 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-10 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-11 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-12 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-13 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-14 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-15 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-17 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-18 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-19 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-2 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-20 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-21 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-22 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-23 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-24 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-25 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-27 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-28 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-29 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-3 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-30 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-4 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-5 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-6 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-7 <class 'pynwb.ecephys.ElectricalSeries'>,  boneeg-3-8 <class 'pynwb.ecephys.ElectricalSeries'> }},
#   'analysis': {},
#   'stimulus': {},
#   'stimulus_template': {},
#   'modules': {'Behavior':
#    Behavior <class 'pynwb.base.ProcessingModule'>
#    Fields:
#      data_interfaces: { Head Direction <class 'pynwb.behavior.CompassDirection'>,  Position <class 'pynwb.behavior.Position'>,  Sleep <class 'fl_extension.Task'>,  Sleep Box <class 'fl_extension.Apparatus'>,  Speed <class 'pynwb.behavior.BehavioralTimeSeries'>,  TrackA <class 'fl_extension.Apparatus'>,  TrackB <class 'fl_extension.Apparatus'>,  W Alternation <class 'fl_extension.Task'> }
#      description: Behavioral variables},
#   'devices': {'NSpike acquisition system':
#    NSpike acquisition system <class 'pynwb.device.Device'>
#    Fields:},
#   'electrode_groups': {'03-01':
#    03-01 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 1 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-02':
#    03-02 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 2 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-03':
#    03-03 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 3 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-04':
#    03-04 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 4 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-05':
#    03-05 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 5 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-06':
#    03-06 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 6 located in ? on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: ?, '03-07':
#    03-07 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 7 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-08':
#    03-08 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 8 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-10':
#    03-10 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 10 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-11':
#    03-11 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 11 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-12':
#    03-12 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 12 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-13':
#    03-13 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 13 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-14':
#    03-14 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 14 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-15':
#    03-15 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 15 located in ? on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: ?, '03-17':
#    03-17 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 17 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-18':
#    03-18 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 18 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-19':
#    03-19 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 19 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-20':
#    03-20 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 20 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-21':
#    03-21 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 21 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-22':
#    03-22 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 22 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-23':
#    03-23 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 23 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-24':
#    03-24 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 24 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-25':
#    03-25 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 25 located in CA3 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA3, '03-27':
#    03-27 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 27 located in ??? on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: ???, '03-28':
#    03-28 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 28 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-29':
#    03-29 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 29 located in CA1 on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: CA1, '03-30':
#    03-30 <class 'pynwb.ecephys.ElectrodeGroup'>
#    Fields:
#      description: tetrode 30 located in Reference on day 3
#      device: NSpike acquisition system <class 'pynwb.device.Device'>
#      location: Reference},
#   'imaging_planes': {},
#   'ic_electrodes': {},
#   'ogen_sites': {},
#   'time_intervals': {},
#   'lab_meta_data': {},
#   'epochs':
#   epochs <class 'pynwb.epoch.TimeIntervals'>
#   Fields:
#     colnames: ('start_time', 'stop_time', 'exposure', 'task', 'apparatus', 'tags')
#     columns: [
#   start_time <class 'pynwb.core.VectorData'>
#   Fields:
#     description: Start time of epoch, in seconds
#   ,
#   stop_time <class 'pynwb.core.VectorData'>
#   Fields:
#     description: Stop time of epoch, in seconds
#   ,
#   exposure <class 'pynwb.core.VectorData'>
#   Fields:
#     description: number of exposures to this environment
#   ,
#   task <class 'pynwb.core.VectorData'>
#   Fields:
#     description: behavioral task for this epoch
#   ,
#   apparatus <class 'pynwb.core.VectorData'>
#   Fields:
#     description: behavioral apparatus for this epoch
#   ,
#   tags_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: tags <class 'pynwb.core.VectorData'>
#   ,
#   tags <class 'pynwb.core.VectorData'>
#   Fields:
#     description: user-defined tags
#   ]
#     description: experimental epochs
#     id: id <class 'pynwb.core.ElementIdentifiers'>,
#   'epoch_tags': set(),
#   'units':
#   units <class 'pynwb.misc.Units'>
#   Fields:
#     colnames: ('cluster_name', 'spike_times', 'obs_intervals', 'electrodes')
#     columns: [
#   cluster_name <class 'pynwb.core.VectorData'>
#   Fields:
#     description: (str) cluster name from clustering software
#   ,
#   spike_times_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: spike_times <class 'pynwb.core.VectorData'>
#   ,
#   spike_times <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the spike times for each unit
#   ,
#   obs_intervals_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: obs_intervals <class 'pynwb.core.VectorData'>
#   ,
#   obs_intervals <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the observation intervals for each unit
#   ,
#   electrodes_index <class 'pynwb.core.VectorIndex'>
#   Fields:
#     target: electrodes <class 'pynwb.core.DynamicTableRegion'>
#   ,
#   electrodes <class 'pynwb.core.DynamicTableRegion'>
#   Fields:
#     description: the electrodes that each spike unit came from
#     table: electrodes <class 'pynwb.core.DynamicTable'>
#   ]
#     description: Autogenerated by NWBFile
#     id: id <class 'pynwb.core.ElementIdentifiers'>,
#   'electrodes':
#   electrodes <class 'pynwb.core.DynamicTable'>
#   Fields:
#     colnames: ('x', 'y', 'z', 'imp', 'location', 'filtering', 'group', 'group_name')
#     columns: [
#   x <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the x coordinate of the channel location
#   ,
#   y <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the y coordinate of the channel location
#   ,
#   z <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the z coordinate of the channel location
#   ,
#   imp <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the impedance of the channel
#   ,
#   location <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the location of channel within the subject e.g. brain region
#   ,
#   filtering <class 'pynwb.core.VectorData'>
#   Fields:
#     description: description of hardware filtering
#   ,
#   group <class 'pynwb.core.VectorData'>
#   Fields:
#     description: a reference to the ElectrodeGroup this electrode is a part of
#   ,
#   group_name <class 'pynwb.core.VectorData'>
#   Fields:
#     description: the name of the ElectrodeGroup this electrode is a part of
#   ]
#     description: metadata about extracellular electrodes
#     id: id <class 'pynwb.core.ElementIdentifiers'>,
#   'experimenter': 'Mattias Karlsson',
#   'experiment_description': 'Recordings from awake behaving rat',
#   'session_id': '/data/mkarlsso/Bon/',
#   'lab': 'Frank Laboratory',
#   'institution': 'UCSF'},
#  '_NWBFile__session_description': 'Converted NSpike data from /data/mkarlsso/Bon/',
#  '_NWBFile__identifier': 'Bon03',
#  '_NWBFile__session_start_time': datetime.datetime(2006, 1, 3, 12, 0, tzinfo=tzoffset(None, -28800)),
#  '_NWBFile__timestamps_reference_time': datetime.datetime(2006, 1, 3, 12, 0, tzinfo=tzoffset(None, -28800)),
#  '_NWBFile__file_create_date': [datetime.datetime(2019, 5, 26, 18, 26, 19, 424669, tzinfo=tzoffset(None, 3600))],
#  'Subject':
#  subject <class 'pynwb.file.Subject'>
#  Fields:
#    description: Long Evans Rat
#    genotype: WT
#    sex: M
#    species: Rat
#    subject_id: Bond}
